# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting nltk==3.5
#   Downloading nltk-3.5.zip (1.4 MB)
# Collecting allennlp==1.0.0
#   Downloading allennlp-1.0.0-py3-none-any.whl (473 kB)
# Collecting allennlp-models==1.0.0
#   Downloading allennlp_models-1.0.0-py3-none-any.whl (282 kB)
# Collecting tqdm==4.54.0
#   Downloading tqdm-4.54.0-py2.py3-none-any.whl (69 kB)
# Collecting click
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: joblib in /opt/venv/lib/python3.7/site-packages (from nltk==3.5->-r ./requirements.txt (line 1)) (0.17.0)
# Collecting regex
#   Downloading regex-2020.11.13-cp37-cp37m-manylinux2014_x86_64.whl (719 kB)
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.1-py2.py3-none-any.whl (308 kB)
# Collecting pytest
#   Downloading pytest-6.1.2-py3-none-any.whl (272 kB)
# Collecting spacy<2.3,>=2.1.0
#   Downloading spacy-2.2.4-cp37-cp37m-manylinux1_x86_64.whl (10.6 MB)
# Requirement already satisfied: scikit-learn in /opt/venv/lib/python3.7/site-packages (from allennlp==1.0.0->-r ./requirements.txt (line 2)) (0.23.2)
# Collecting transformers<2.12,>=2.9
#   Downloading transformers-2.11.0-py3-none-any.whl (674 kB)
# Requirement already satisfied: numpy in /opt/venv/lib/python3.7/site-packages (from allennlp==1.0.0->-r ./requirements.txt (line 2)) (1.19.4)
# Collecting torch<1.6.0,>=1.5.0
#   Downloading torch-1.5.1-cp37-cp37m-manylinux1_x86_64.whl (753.2 MB)
# Requirement already satisfied: scipy in /opt/venv/lib/python3.7/site-packages (from allennlp==1.0.0->-r ./requirements.txt (line 2)) (1.5.4)
# Collecting overrides==3.0.0
#   Downloading overrides-3.0.0.tar.gz (4.5 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.2-py2.py3-none-any.whl (36 kB)
# Collecting jsonnet>=0.10.0; sys_platform != "win32"
#   Downloading jsonnet-0.17.0.tar.gz (259 kB)
# Collecting filelock<3.1,>=3.0
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: requests>=2.18 in /opt/venv/lib/python3.7/site-packages (from allennlp==1.0.0->-r ./requirements.txt (line 2)) (2.25.0)
# Collecting boto3
#   Downloading boto3-1.16.25-py2.py3-none-any.whl (129 kB)
# Collecting h5py
#   Downloading h5py-3.1.0-cp37-cp37m-manylinux1_x86_64.whl (4.0 MB)
# Collecting py-rouge==1.1
#   Downloading py_rouge-1.1-py3-none-any.whl (56 kB)
# Collecting conllu==3.0
#   Downloading conllu-3.0-py2.py3-none-any.whl (14 kB)
# Collecting word2number>=1.1
#   Downloading word2number-1.1.zip (9.7 kB)
# Collecting protobuf>=3.8.0
#   Downloading protobuf-3.14.0-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
# Requirement already satisfied: six in /opt/venv/lib/python3.7/site-packages (from tensorboardX>=1.2->allennlp==1.0.0->-r ./requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/venv/lib/python3.7/site-packages (from pytest->allennlp==1.0.0->-r ./requirements.txt (line 2)) (20.3.0)
# Collecting pluggy<1.0,>=0.12
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: packaging in /opt/venv/lib/python3.7/site-packages (from pytest->allennlp==1.0.0->-r ./requirements.txt (line 2)) (20.4)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /opt/venv/lib/python3.7/site-packages (from pytest->allennlp==1.0.0->-r ./requirements.txt (line 2)) (2.0.0)
# Collecting py>=1.8.2
#   Downloading py-1.9.0-py2.py3-none-any.whl (99 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.4-cp37-cp37m-manylinux2014_x86_64.whl (20 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.4-cp37-cp37m-manylinux2014_x86_64.whl (284 kB)
# Collecting thinc==7.4.0
#   Downloading thinc-7.4.0-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: setuptools in /opt/venv/lib/python3.7/site-packages (from spacy<2.3,>=2.1.0->allennlp==1.0.0->-r ./requirements.txt (line 2)) (50.3.2)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.8.0-py3-none-any.whl (23 kB)
# Collecting blis<0.5.0,>=0.4.0
#   Downloading blis-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.4-cp37-cp37m-manylinux2014_x86_64.whl (293 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.4-cp37-cp37m-manylinux2014_x86_64.whl (35 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/venv/lib/python3.7/site-packages (from scikit-learn->allennlp==1.0.0->-r ./requirements.txt (line 2)) (2.1.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.94-cp37-cp37m-manylinux2014_x86_64.whl (1.1 MB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.43.tar.gz (883 kB)
# Collecting tokenizers==0.7.0
#   Downloading tokenizers-0.7.0-cp37-cp37m-manylinux1_x86_64.whl (5.6 MB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Requirement already satisfied: idna<3,>=2.5 in /opt/venv/lib/python3.7/site-packages (from requests>=2.18->allennlp==1.0.0->-r ./requirements.txt (line 2)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/venv/lib/python3.7/site-packages (from requests>=2.18->allennlp==1.0.0->-r ./requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.7/site-packages (from requests>=2.18->allennlp==1.0.0->-r ./requirements.txt (line 2)) (2020.11.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/venv/lib/python3.7/site-packages (from requests>=2.18->allennlp==1.0.0->-r ./requirements.txt (line 2)) (1.26.2)
# Collecting botocore<1.20.0,>=1.19.25
#   Downloading botocore-1.19.25-py2.py3-none-any.whl (6.9 MB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Collecting cached-property; python_version < "3.8"
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/venv/lib/python3.7/site-packages (from packaging->pytest->allennlp==1.0.0->-r ./requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /opt/venv/lib/python3.7/site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest->allennlp==1.0.0->-r ./requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/venv/lib/python3.7/site-packages (from botocore<1.20.0,>=1.19.25->boto3->allennlp==1.0.0->-r ./requirements.txt (line 2)) (2.8.1)
# Building wheels for collected packages: nltk, overrides, jsonnet, word2number, sacremoses, future
#   Building wheel for nltk (setup.py): started
#   Building wheel for nltk (setup.py): finished with status 'done'
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434675 sha256=9461a9c8a3dfd7ca8ffbeaee1680e5eab0a238b3c905d9b832d17eed82504d80
#   Stored in directory: /home/jovyan/.cache/pip/wheels/45/6c/46/a1865e7ba706b3817f5d1b2ff7ce8996aabdd0d03d47ba0266
#   Building wheel for overrides (setup.py): started
#   Building wheel for overrides (setup.py): finished with status 'done'
#   Created wheel for overrides: filename=overrides-3.0.0-py3-none-any.whl size=5668 sha256=40b351e9a85967e0c6b82c9e0548679b3ee36817e67c65a3f836ce07d95a1034
#   Stored in directory: /home/jovyan/.cache/pip/wheels/7d/c6/bf/bff44a9cc6c899e2d77ec968b2d0707616a3d66e4ebefb2411
#   Building wheel for jsonnet (setup.py): started
#   Building wheel for jsonnet (setup.py): finished with status 'done'
#   Created wheel for jsonnet: filename=jsonnet-0.17.0-cp37-cp37m-linux_x86_64.whl size=335229 sha256=9433542d65c7cb5bf2583238f5622e168c4a5ed4a36b1bc2cf17306a42c0df3f
#   Stored in directory: /home/jovyan/.cache/pip/wheels/1c/28/7e/287c6b19f7161bb03c6986a3c46b51d0d7d9a1805346634e3a
#   Building wheel for word2number (setup.py): started
#   Building wheel for word2number (setup.py): finished with status 'done'
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5586 sha256=f2e84e19979554ae7ef637654714030296cf3caee9a4c6bbc3d1cabb47c82405
#   Stored in directory: /home/jovyan/.cache/pip/wheels/4b/c3/77/a5f48aeb0d3efb7cd5ad61cbd3da30bbf9ffc9662b07c9f879
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=893259 sha256=1f11ffb37e5eb6fef86ac208862724584dac1ecae9b319fb0ee6b72da1b4a0dc
#   Stored in directory: /home/jovyan/.cache/pip/wheels/69/09/d1/bf058f7d6fa0ecba2ce7c66be3b8d012beb4bf61a6e0c101c0
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=924df4f4003534329fba5014d5201048cafd2ac6072904c9af870e184870edda
#   Stored in directory: /home/jovyan/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built nltk overrides jsonnet word2number sacremoses future
# Installing collected packages: click, regex, tqdm, nltk, protobuf, tensorboardX, pluggy, iniconfig, toml, py, pytest, murmurhash, cymem, preshed, catalogue, srsly, plac, blis, wasabi, thinc, spacy, sentencepiece, sacremoses, tokenizers, filelock, transformers, future, torch, overrides, jsonpickle, jsonnet, jmespath, botocore, s3transfer, boto3, cached-property, h5py, allennlp, py-rouge, conllu, word2number, allennlp-models
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.0.0.dev0
#     Uninstalling pluggy-1.0.0.dev0:
#       Successfully uninstalled pluggy-1.0.0.dev0
# Successfully installed allennlp-1.0.0 allennlp-models-1.0.0 blis-0.4.1 boto3-1.16.25 botocore-1.19.25 cached-property-1.5.2 catalogue-1.0.0 click-7.1.2 conllu-3.0 cymem-2.0.4 filelock-3.0.12 future-0.18.2 h5py-3.1.0 iniconfig-1.1.1 jmespath-0.10.0 jsonnet-0.17.0 jsonpickle-1.4.2 murmurhash-1.0.4 nltk-3.5 overrides-3.0.0 plac-1.1.3 pluggy-0.13.1 preshed-3.0.4 protobuf-3.14.0 py-1.9.0 py-rouge-1.1 pytest-6.1.2 regex-2020.11.13 s3transfer-0.3.3 sacremoses-0.0.43 sentencepiece-0.1.94 spacy-2.2.4 srsly-1.0.4 tensorboardX-2.1 thinc-7.4.0 tokenizers-0.7.0 toml-0.10.2 torch-1.5.1 tqdm-4.54.0 transformers-2.11.0 wasabi-0.8.0 word2number-1.1
# WARNING: You are using pip version 20.2.4; however, version 20.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.
