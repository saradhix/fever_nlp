# %%
import os
import json
import sys
WIKI_FOLDER = '/datasets/wiki-dump/wiki-pages/'
OUTPUT_FILE = '/datasets/wiki-dump/combined_replaced_pronouns'

# %%
def get_wiki_files(folderpath):
    files = os.listdir(folderpath)
    files = [os.path.join(folderpath,x) for x in files]
    return files

# %%
def mainfn():
    ft=open(OUTPUT_FILE, 'w+')
    print("Hello")
    files = get_wiki_files(WIKI_FOLDER)
    print(files)
    for filename in files:
        print("Processing file", filename)
        fp=open(filename, 'r')
        for line in fp:
            obj = json.loads(line.strip())
            new_obj = {}
            #print(obj)
            page_id = obj['id']
            page_id_spaces = page_id.replace("-", " ")
            page_id_spaces = page_id.replace("_", " ")
            replace_dict = {'He': page_id_spaces, 'he': page_id_spaces, 'She':
                            page_id_spaces, 'she': page_id_spaces}
            new_obj[page_id]= []
            print("Page ID=", page_id)
            long_lines = obj['lines']
            #print("Long lines=", long_lines)
            for long_line in long_lines.split('\n'):
                fragments = long_line.split('\t')
                if len(fragments) <= 0:
                    print("ERROR: Less number of fragments for the line XXX", long_line ,"XXX")
                    continue
                line_number = fragments[0]
                #print("Fragments=", fragments)
                line = ' '.join(fragments[1:])
                #print("#", line_number, "line=", line)
                if len(line) <=1: continue
                words = line.split()
                words = [replace_dict.get(n, n) for n in words]
                line = ' '.join(words)
                new_obj[page_id].append((line_number, line))
            ft.write(json.dumps(new_obj)+'\n')
            #print(new_obj)
            #sys.exit()



        fp.close()
    ft.close()

# %%
mainfn()
# Out:
# Page ID= Đoàn_Viết_Hoạt
# Page ID= YARS
# Page ID= Yuriy_Nazarov_-LRB-actor-RRB-
# Page ID= Wójcina
# Page ID= Xelha_-LRB-disambiguation-RRB-
# Page ID= Əniqoba
# Page ID= Zhou_Yan_-LRB-curler-RRB-
# Page ID= Zbigniew_Spruch
# Page ID= Yoav_Galant
# Page ID= Élie_Ducommun
# Page ID= Xavier_Domènech_i_Sampere
# Page ID= Yarali-ye_Olya
# Page ID= Zwelakhe_Sisulu
# Page ID= Za_socijalističku_Jugoslaviju
# Page ID= Škrip
# Page ID= Đinh_dynasty
# Page ID= Xavier_Technical_College
# Page ID= Yola
# Page ID= XO_-LRB-song-RRB-
# Page ID= Xuân_Trạch
# Page ID= Yordan_Todorov_-LRB-footballer,_born_November_1981-RRB-
# Page ID= Yoshihiro_Shiroishi
# Page ID= Wronki_Prison
# Page ID= Zrinska
# Page ID= Łódź_Biennale
# Page ID= XHEMG-FM
# Page ID= Zygoballus_nervosus
# Page ID= Zsolt_Beöthy
# Page ID= Yummy-COLON-_the_Last_Days_of_a_Southside_Shorty
# Page ID= İzmir_Institute_of_Technology
# Page ID= Zygomatic_branches_of_the_facial_nerve
# Page ID= Zassenhaus_group
# Page ID= Zhiyuan_Era
# Page ID= Zbraslav_Monastery
# Page ID= Çaykenarı,_Korkuteli
# Page ID= Zaufensgraben
# Page ID= À_l'ombre
# Page ID= Yes_Sir_-LRB-Capone-N-Noreaga_song-RRB-
# Page ID= Zgornji_Razbor
# Page ID= Zero-configuration_networking
# Page ID= Wu_Dixi
# Page ID= Zola_Matumona
# Page ID= `Amum
# Page ID= Émile_Sagot
# Page ID= Youth_Employment_Service
# Page ID= Wuchang_bream
# Page ID= Yara_dos_Santos
# Page ID= Čulo
# Page ID= Xcast
# Page ID= Yves_Rocard
# Page ID= ZFC_Meuselwitz
# Page ID= Zhanjiang_dialect
# Page ID= Zahorski_theorem
# Page ID= Xylophanes_pistacina
# Page ID= Ōkute-juku
# Page ID= Zacorisca_aptycha
# Page ID= Wysoka,_Masovian_Voivodeship
# Page ID= Xia_Huan
# Page ID= Zhalan_Rashid
# Page ID= Yegakor
# Page ID= Zollgrenzschutz
# Page ID= Zaeeropsis_godeffroyi
# Page ID= Wright_-LRB-English_cricketer-RRB-
# Page ID= Xatax
# Page ID= Ölmstad
# Page ID= Çäkçäk
# Page ID= York_by-election,_1937
# Page ID= XMission
# Page ID= Yurko_Hnatkovsky
# Page ID= XHNG-FM
# Page ID= Yis_language
# Page ID= Álvaro_Uribe
# Page ID= Xyris_elliottii
# Page ID= Yamato_691
# Page ID= Yongmyongsa
# Page ID= Óscar_Sánchez_Fuentes
# Page ID= Zmyślona_Słupska
# Page ID= Yeung_Hok-ling
# Page ID= Élisabeth_Chaud
# Page ID= Yakubu_Tali
# Page ID= Yılanlı,_Kalecik
# Page ID= Yodo_River
# Page ID= Yukari_Takemoto
# Page ID= Xavier_Pelegrí
# Page ID= Yuri_Mamontyev
# Page ID= Zardin_Kahir
# Page ID= Yosef_Shapira_-LRB-judge-RRB-
# Page ID= Šuica_-LRB-river-RRB-
# Page ID= Ángel_Navarro
# Page ID= Zhao_Mausoleum_-LRB-Tang_dynasty-RRB-
# Page ID= Żdżarka
# Page ID= Zalesie_Królewskie
# Page ID= Xavier_Briggs
# Page ID= Yeləkəsən
# Page ID= Öndörkhangai,_Uvs
# Page ID= Zaza_Sikharulidze
# Page ID= Zamyn-Üüd
# Page ID= XBR_-LRB-Sony-RRB-
# Page ID= Y._Gadilingana_Goud
# Page ID= Yassi_-LRB-album-RRB-
# Page ID= Yalkut_Shimoni
# Page ID= Yajaw_Te'_K'inich_II
# Page ID= Wólka_Ołudzka
# Page ID= Zehra_Laila_Javeri
# Page ID= Yevgeny_Grishin_-LRB-speed_skater-RRB-
# Page ID= Zenith_Data_Systems
# Page ID= Wu_Changshuo
# Page ID= Zheng_Jian
# Page ID= Žibrše
# Page ID= Xyroptila_monomotapa
# Page ID= Yodogawa
# Page ID= Zeya,_Russia
# Page ID= Yemen_national_football_team_all-time_record
# Page ID= Yang_Kyong-hui
# Page ID= Zuidtangent
# Page ID= Zadar
# Page ID= Ștefan_S._Nicolau
# Page ID= Zmożna_Wola
# Page ID= Yorke_Allen,_Jr.
# Page ID= Yu_Jae-hung
# Page ID= Žilina_-LRB-disambiguation-RRB-
# Page ID= `Ajmiyah
# Page ID= Wronowo
# Page ID= Zombie_Zero
# Page ID= Zaw_Linn_Tun
# Page ID= Zygophyllum_album
# Page ID= Üçtəpə,_Baku
# Page ID= Ximeng_Va_Autonomous_County
# Page ID= Yaqub_al-Ghusayn
# Page ID= Wyandotte_Township,_Pennington_County,_Minnesota
# Page ID= Zoran_Đerić
# Page ID= Zell,_South_Dakota
# Page ID= Xiafs
# Page ID= Zhang_Yin
# Page ID= Zambia_at_the_Paralympics
# Page ID= Zerkten
# Page ID= Zenamorpha_discophoralis
# Page ID= Yin
# Page ID= Wuliangye
# Page ID= Yoshitaka_Takeya
# Page ID= Young-Noyes_House
# Page ID= You're_a_Mean_One,_Mr._Grinch
# Page ID= Yul_Servo
# Page ID= Yann_Tomita
# Page ID= Čudovita_potovanja_Zajca_Rona
# Page ID= Yoshimichi
# Page ID= Zilzie
# Page ID= Yan_Emperor
# Page ID= Yed_District
# Page ID= Zatrephes_rosella
# Page ID= XHZS-FM_-LRB-Sinaloa-RRB-
# Page ID= Zawidz_Mały
# Page ID= Zomba_Group_of_Companies
# Page ID= Zawiść
# Page ID= Ángel_Zamarripa
# Page ID= Ávila_-LRB-Spanish_Congress_electoral_district-RRB-
# Page ID= Yuki_Chikudate
# Page ID= Zapole,_Podkarpackie_Voivodeship
# Page ID= Zhang_Da'an
# Page ID= Yevgeni_Smertin
# Page ID= Yoshinori_Takeuchi
# Page ID= Zhou_Yu_-LRB-table_tennis-RRB-
# Page ID= Xu_Chongde
# Page ID= Yevhen_Lapinsky
# Page ID= Zelin_Coffee_House
# Page ID= Xamontarupt
# Page ID= You're_My_World_-LRB-Emilia_Rydberg_song-RRB-
# Page ID= Wykroty,_West_Pomeranian_Voivodeship
# Page ID= Zambiya
# Page ID= Zoo_Friends
# Page ID= İnanç
# Page ID= Ádám_Balajti
# Page ID= Yarra_Junction_railway_station
# Page ID= Édson_Ramalho_dos_Santos
# Page ID= Yevhen_Makarenko
# Page ID= Załuskie_Kościelne
# Page ID= Yazalde_Gomes_Pinto
# Page ID= Yujiulü_Dengshuzi
# Page ID= Ännikse
# Page ID= Yasmin_Abbasey
# Page ID= YRU
# Page ID= Wulf_Kirsten
# Page ID= Zodi
# Page ID= Young_Chang
# Page ID= Yogesh_Nauhwar
# Page ID= Zhangjiajie
# Page ID= Župica_Lake
# Page ID= Y_Niwl
# Page ID= Yang_Xuanzhi
# Page ID= YJ-22
# Page ID= X-Fly
# Page ID= ¿Con_qué_sueñas?
# Page ID= Zeppelin-Staaken_R.XVI
# Page ID= Yauli,_Huancavelica
# Page ID= Yaban
# Page ID= Węgrzce
# Page ID= Your_Body_Sub_Atomic
# Page ID= Ziggy_Hasbrook
# Page ID= ZeniMax_Online_Studios
# Page ID= Zoran_Nikitović
# Page ID= Zechlin
# Page ID= Yuksek
# Page ID= You_Are_the_Avalanche
# Page ID= Yukihiro_Takahashi
# Page ID= Xavier_University
# Page ID= Yi_Insang
# Page ID= Zielina
# Page ID= Ādityas
# Page ID= Šuman_Topla
# Page ID= Şatırlı,_Jalilabad
# Page ID= Yossi_Melman
# Page ID= Zelotibia
# Page ID= Wu_Chao_-LRB-weightlifter-RRB-
# Page ID= Yongmun-dong
# Page ID= Zinaida_Irutė_Dargienė
# Page ID= Yuya_Hikichi
# Page ID= Wycherley
# Page ID= Yoon_Soung-min
# Page ID= Zuhal
# Page ID= Ōnori_Station
# Page ID= Yumiko_Shaku
# Page ID= Yanco_Agricultural_High_School
# Page ID= Xylogalacturonan_beta-1,3-xylosyltransferase
# Page ID= Xylulose
# Page ID= Čiekurkalns
# Page ID= Zobahan_Freeway
# Page ID= Zardari
# Page ID= Xu_Yuanquan
# Page ID= Yenişehir_Airport
# Page ID= Xiyuan_Temple
# Page ID= Yuji_Naka
# Page ID= Zugurma_Game_Reserve
# Page ID= Zagreb_Fair
# Page ID= Yasuji
# Page ID= Zygaenosia_eximia
# Page ID= Zhanibek_Alimkhanuly
# Page ID= Zarcero_-LRB-canton-RRB-
# Page ID= Yak_shaving
# Page ID= Zwierzyniec,_Krasnystaw_County
# Page ID= You_Know_Me_Better_Than_That
# Page ID= Xenosoma_flaviceps
# Page ID= Xianshuigu
# Page ID= Yeak_Laom
# Page ID= Zimbabwean_Americans
# Page ID= Wyld_File
# Page ID= Yuma_creation_myth
# Page ID= İnkılâpçı
# Page ID= Xfinity_Center_-LRB-Mansfield,_Massachusetts-RRB-
# Page ID= Żabiki
# Page ID= Zsolt_Azari
# Page ID= Zhu_Wenxin
# Page ID= Yuri_Nakamura
# Page ID= Zoltán_Demeter
# Page ID= Žaovine
# Page ID= Zeus_-LRB-disambiguation-RRB-
# Page ID= Yusif_Yakubu
# Page ID= Youtube-dl
# Page ID= Zweli_Mkhize
# Page ID= Yorimitsu
# Page ID= Writers_Guild_of_America_Award_for_Television-COLON-_Long_Form_–_Adapted
# Page ID= Xeni_Gwet'in
# Page ID= Òscar_Vendrell_Corrons
# Page ID= Yeongnam
# Page ID= Łapczyna_Wola
# Page ID= Xhelal_Pasha_Zogolli
# Page ID= Yulfira_Barkah
# Page ID= Ōdomari_Station
# Page ID= Žarko_Lazetić
# Page ID= Zé_Teodoro
# Page ID= Ypsolopha_aleutianella
# Page ID= Zegujani_oil_field
# Page ID= Yamato_Province
# Page ID= Çorakdere,_Vezirköprü
# Page ID= Țebea_River
# Page ID= Zangpo
# Page ID= Österskär
# Page ID= İmircik,_Elmalı
# Page ID= Žalesys
# Page ID= Yekaterina_Mulyuk-Timofeyeva
# Page ID= Zgorzałe
# Page ID= Yoel_Sela
# Page ID= Yurats_language
# Page ID= Yemane
# Page ID= Yuuta_Takahashi
# Page ID= Wu_Renbi
# Page ID= YCS
# Page ID= Wye_Jamison_Allanbrook
# Page ID= Zolgörən
# Page ID= Zambak
# Page ID= Xserve
# Page ID= You're_Beautiful_-LRB-TV_series-RRB-
# Page ID= X̣
# Page ID= Łączna,_Świętokrzyskie_Voivodeship
# Page ID= Wróblowice,_Lower_Silesian_Voivodeship
# Page ID= Zhang_Zhannan
# Page ID= Łukasz_Czapla
# Page ID= Šárka
# Page ID= Zygmunt_Żuławski
# Page ID= YFZ_Ranch
# Page ID= Zachary_Vlahos
# Page ID= Yves_Triantafyllos
# Page ID= Șteaza_River
# Page ID= Zushi,_Kanagawa
# Page ID= Xikou
# Page ID= Zulu_-LRB-1964_film-RRB-
# Page ID= Yarara_-LRB-disambiguation-RRB-
# Page ID= Zosin,_Ryki_County
# Page ID= Yemeni_constitutional_referendum,_1991
# Page ID= Ólavur
# Page ID= Yakuza_Kiwami
# Page ID= Zelooperz
# Page ID= XEYTM-AM
# Page ID= Yurimaguas_District
# Page ID= Zhalti_Bryag
# Page ID= Yevgeny_Lomach
# Page ID= Złota_Wieś
# Page ID= Xarolla_Windmill
# Page ID= Xplosión
# Page ID= Zarafshan_-LRB-disambiguation-RRB-
# Page ID= XXXombies
# Page ID= Édouard_Montpetit
# Page ID= Zhydachiv
# Page ID= Łyszkiewicz_Apartment
# Page ID= İki_Dünya_Arasında
# Page ID= Zeke_Meyer
# Page ID= Yelyzaveta_Bochkaryova
# Page ID= Zalakaros
# Page ID= Wyrębiny
# Page ID= Đỗ_Thị_Anh
# Page ID= Yamaha_P-250
# Page ID= Şubanı
# Page ID= Çiçek
# Page ID= XHGEO-FM
# Page ID= Åsa_Solberg_Iversen
# Page ID= Yamaha_YZF1000R_Thunderace
# Page ID= Zoe_Țapu
# Page ID= XHITD-FM
# Page ID= Zunera_Ishaq
# Page ID= Youssef_Salim_Karam
# Page ID= Yuri_Salnikov
# Page ID= Zauvijek_tvoj
# Page ID= Yuji_Nakamura
# Page ID= Wrestling_at_the_2008_Summer_Olympics_–_Men's_freestyle_60_kg
# Page ID= Yellow_Banks,_Kentucky
# Page ID= Yusuf_Isa_Halim
# Page ID= XHEPR-FM
# Page ID= Ōnomachi_Station
# Page ID= You'll_Need_Somebody_on_Your_Bond
# Page ID= Yuu_Shimaka
# Page ID= Ōno_District,_Gifu
# Page ID= Yunho
# Page ID= Zibusiso_Mkhwanazi
# Page ID= Zak_Surety
# Page ID= Yellow_fluorescent_protein
# Page ID= Zabłocie,_Silesian_Voivodeship
# Page ID= Łówkówiec
# Page ID= Zardband
# Page ID= Zarnan,_Tehran
# Page ID= Álvaro_Betancourt
# Page ID= Yukon_Eric
# Page ID= Yousef_Masrahi
# Page ID= Yamoto
# Page ID= Xylochora
# Page ID= Zaq
# Page ID= Łukasz_Masiak
# Page ID= Wronskian
# Page ID= X-type_histiocytosis
# Page ID= Zarajec
# Page ID= Émile_Mbamba
# Page ID= Yuki_Uchiyama
# Page ID= Yuri_Knorozov
# Page ID= Zdzisław_Karczewski
# Page ID= Øystein_Bache
# Page ID= Young_Thug
# Page ID= Øystein_Lønn
# Page ID= Wyoming,_Wisconsin
# Page ID= You_Are_So_Good_to_Me
# Page ID= Zirgar-e_Sofla
# Page ID= École_Marie_Félicité_Brosset
# Page ID= Zabiele,_Łuków_County
# Page ID= Yager_Creek
# Page ID= Zufer_Avdija
# Page ID= Zaac_Pick
# Page ID= ZISD
# Page ID= Ypsolopha_yasudai
# Page ID= Åsmund_Sveen
# Page ID= Çolaknebi,_Aksaray
# Page ID= Yue_Minjun
# Page ID= Yana_Noskova
# Page ID= Youth_Bandy_World_Championship
# Page ID= Zwanzig_projection_operator
# Page ID= Zenit_-LRB-sports_society-RRB-
# Page ID= Yawar,_Papua_New_Guinea
# Page ID= Ziradei_-LRB-Vidhan_Sabha_constituency-RRB-
# Page ID= Yacine_Babouche
# Page ID= Yamur_Lake_grunter
# Page ID= Zabrđe_-LRB-Priboj-RRB-
# Page ID= Zhang_Xin_-LRB-businesswoman-RRB-
# Page ID= Y.Ramavaram
# Page ID= Åke_Andersson_-LRB-athlete-RRB-
# Page ID= Émilie_d'Oultremont
# Page ID= Z39.87
# Page ID= Émile_Espérandieu
# Page ID= Šlokenbeka_Castle
# Page ID= Yin_Hang
# Page ID= Yamethin_Township
# Page ID= Xpress
# Page ID= Yu_Xie
# Page ID= Çankırıspor
# Page ID= Zoveyr-e_Kharamzeh
# Page ID= Yoshiki
# Page ID= Zainab_Al_Askari
# Page ID= You're_Too_Straight_to_Love_Me
# Page ID= Young_Deenay
# Page ID= Yogetor_bellus
# Page ID= Wulfsmoor
# Page ID= Zaręby-Krztęki
# Page ID= Ángel_Sánchez_-LRB-referee-RRB-
# Page ID= Ælfric_-LRB-bishop_of_Hereford-RRB-
# Page ID= Zero-byte_file
# Page ID= Yahya_Dhabiani
# Page ID= Zeitschrift_für_die_Alttestamentliche_Wissenschaft
# Page ID= Xiaojie
# Page ID= Yunnanolepis
# Page ID= Zawichost
# Page ID= Yorkshire_Stingo
# Page ID= Zbigniew_Miązek
# Page ID= Zizula_hylax
# Page ID= Zamorano_Eighty
# Page ID= Yuri_Osipyan
# Page ID= Yamaha_CS1x
# Page ID= Únehle
# Page ID= Yann-Ber_Kalloc'h
# Page ID= You_-LRB-Phillip_LaRue_album-RRB-
# Page ID= Zeng_Chunlei
# Page ID= Zavrh_pri_Trojanah
# Page ID= Young_Ejecta
# Page ID= Èrs_people
# Page ID= Wysoka_Wielka,_Greater_Poland_Voivodeship
# Page ID= You_Were_Never_Uglier
# Page ID= Yalan_Dünya
# Page ID= Wrząca,_Pabianice_County
# Page ID= Yasonna_Laoly
# Page ID= Yayoi_pottery
# Page ID= Zerind
# Page ID= You_Deserve_Everything
# Page ID= Zoran_Cvetković
# Page ID= Zodarion_costapratae
# Page ID= Wüst
# Page ID= Zeletovo
# Page ID= Zichem
# Page ID= Zatoichi's_Pilgrimage
# Page ID= Yaringa_Marine_National_Park
# Page ID= Zamora_Province_-LRB-Venezuela-RRB-
# Page ID= Young_Malang
# Page ID= Øhavsstien
# Page ID= Zawady,_Silesian_Voivodeship
# Page ID= Zieleniec,_Opole_Voivodeship
# Page ID= Xerse_-LRB-Bononcini-RRB-
# Page ID= Zeynalan
# Page ID= Yaksik
# Page ID= Yeadon_Town_Hall
# Page ID= Álvaro_Arias
# Page ID= Zhao_Chuandong
# Page ID= Young_Communist_League_of_Western_Ukraine
# Page ID= Álvaro_Fernández
# Page ID= Yombiro
# Page ID= Zimbabwean_cricket_team_in_the_West_Indies_in_2012–13
# Page ID= Özsoy
# Page ID= Zhonghelu_Church
# Page ID= Wrestling_at_the_2011_Pan_American_Games_–_Women's_Freestyle_63_kg
# Page ID= Żupny_Castle
# Page ID= Šepšin
# Page ID= Yetkin_Dikinciler
# Page ID= Åsta_Gudbrandsdatter
# Page ID= Wymysłowo,_Wągrowiec_County
# Page ID= Łukaszewicz
# Page ID= Yuzuru_Hanyu
# Page ID= Yukihiro_Ozaki
# Page ID= Yser_Testament
# Page ID= Xunta_de_Galicia
# Page ID= Zinneke_Parade
# Page ID= YTM
# Page ID= Yutaka_Tsuchiya
# Page ID= Zener
# Page ID= Škaljari
# Page ID= Zine
# Page ID= Yi’ong
# Page ID= Étang_de_Brouquenat
# Page ID= Yellow-headed_brush_finch
# Page ID= Şahmansurlu
# Page ID= Üçbaş,_Kızılcahamam
# Page ID= Xerochrysum_subundulatum
# Page ID= Çıraqlı,_Shamakhi
# Page ID= Yenowine-Nichols-Collins_House
# Page ID= Yasufumi_Fujino
# Page ID= Zarcero_-LRB-Canton-RRB-
# Page ID= ‘Ad
# Page ID= York_News-Times
# Page ID= École_pour_l'informatique_et_les_techniques_avancées
# Page ID= Zabrodzie,_West_Pomeranian_Voivodeship
# Page ID= Yellow_Earth
# Page ID= Xinjiang_Tianshan_Leopard_F.C.
# Page ID= Yatarō_Mishima
# Page ID= Yokozawa_Shōgen
# Page ID= Çatören_Dam
# Page ID= Zezuj
# Page ID= °Cmaj9
# Page ID= Wrestling_at_the_1984_Summer_Olympics_–_Men's_Greco-Roman_82_kg
# Page ID= Wyongah,_New_South_Wales
# Page ID= Yan,_Marquis_of_Tian
# Page ID= Wszyscy_kochają_Romana
# Page ID= Ågren
# Page ID= Yelizarovo
# Page ID= Zhengzhou_University_Sci-Tech_Park_Station
# Page ID= Étienne-Claude_Lagueux
# Page ID= Youssou_Lo
# Page ID= Yuqiang
# Page ID= Żółkwy
# Page ID= École_Évangéline
# Page ID= Xylia_xylocarpa
# Page ID= Yongbongsan
# Page ID= Álbum_-LRB-Lu_album-RRB-
# Page ID= Zhenjiang_Huasa_F.C.
# Page ID= Łaziska,_Pomeranian_Voivodeship
# Page ID= Yu_Hyun-mok
# Page ID= Zulte
# Page ID= Zwijndrecht,_Belgium
# Page ID= Čapkovič
# Page ID= Wyllie_Colliery
# Page ID= Zgornji_Hotič
# Page ID= Zakharov_-LRB-rural_locality-RRB-
# Page ID= Zymotic_disease
# Page ID= Île-à-Vache
# Page ID= Yukon_general_election,_2000
# Page ID= Zephronia
# Page ID= Zanthoxylum_brachyacanthum
# Page ID= Zen_Noir
# Page ID= Yellow-vented_warbler
# Page ID= Zadig
# Page ID= Çakyamuni
# Page ID= Zolotukhin
# Page ID= Xi_Scorpii
# Page ID= Zeuxis_-LRB-gastropod-RRB-
# Page ID= Wrestling_at_the_2012_Summer_Olympics_–_Women's_freestyle_55_kg
# Page ID= Zagozdac
# Page ID= Zoltán_Király
# Page ID= Zoé_-LRB-given_name-RRB-
# Page ID= Ypsolopha_costibasella
# Page ID= Zervreilahorn
# Page ID= École_secondaire_Mont-Bleu
# Page ID= Xawery_Czernicki
# Page ID= Yusufiyah
# Page ID= Zaplous_annulatus
# Page ID= Yeni_Zod
# Page ID= Xv_-LRB-software-RRB-
# Page ID= Úrkút
# Page ID= You_Comb_Her_Hair
# Page ID= Zeitschrift_für_Angewandte_Mathematik_und_Physik
# Page ID= YC_-LRB-rapper-RRB-
# Page ID= Wrestling_at_the_1992_Summer_Olympics_–_Men's_Greco-Roman_68_kg
# Page ID= Yenatha
# Page ID= ↓
# Page ID= Åkerman
# Page ID= XHZQ-FM
# Page ID= Zaoqiang_County
# Page ID= Yaar_Kannan
# Page ID= ZIL-4104
# Page ID= Xiangtan_County
# Page ID= Zawadka,_Lublin_Voivodeship
# Page ID= Yanaka
# Page ID= Zarębin
# Page ID= Zlatarić
# Page ID= Zacharias_Sexual_Abuse_Center
# Page ID= Zdzisławice,_Lublin_Voivodeship
# Page ID= Yerukala
# Page ID= Zunfthaus_zur_Zimmerleuten
# Page ID= Xanthophyllum_ovatifolium
# Page ID= Yekaviyeh-ye_Yek
# Page ID= You're_a_Big_Boy_Now_-LRB-album-RRB-
# Page ID= Úrvalsdeild_Women's_Domestic_Player_of_the_Year
# Page ID= Younger_Generation
# Page ID= Zalog_pri_Škofljici
# Page ID= Ørsta–Volda_Airport,_Hovden
# Page ID= Wszerzecz
# Page ID= Zora_Kostková
# Page ID= Yucatan_woodpecker
# Page ID= You_and_the_Night_and_the_Music_-LRB-Mal_Waldron_album-RRB-
# Page ID= Yoo_Ah-in
# Page ID= Yulandi_van_der_Merwe
# Page ID= Zhou_dynasty_-LRB-690–705-RRB-
# Page ID= Yousef_Al-Askari
# Page ID= Żebry-Sławki
# Page ID= ZFP92
# Page ID= Xubida_minorella
# Page ID= Țintești
# Page ID= Yeoju_Station
# Page ID= Zakorenje
# Page ID= Ƹ
# Page ID= Ömer_Yurtseven
# Page ID= Óscar_Moreno
# Page ID= Ypsolopha_vittella
# Page ID= Yale_Law_School
# Page ID= Zayed_Center_for_Coordination_and_Follow-Up
# Page ID= Wynkoop_House
# Page ID= Yevgeni_Aleksandrovich_Karev
# Page ID= Štanjel
# Page ID= Yedioth_Tel_Aviv
# Page ID= You_Took_Advantage_of_Me
# Page ID= Zygaena_brizae
# Page ID= Wullschlaegelia
# Page ID= Zeiss_Otus_1.4/55
# Page ID= Zongo
# Page ID= Émile_Gaboriau
# Page ID= Zimbabwean_Australians
# Page ID= Yahagibashi_Station
# Page ID= Šargovac
# Page ID= ZNF707
# Page ID= Østfold_University_College
# Page ID= Yahdul-Lim
# Page ID= XHJR-FM
# Page ID= Yaba_College
# Page ID= Zoumana_Camara
# Page ID= Wycliffe_and_the_Tangled_Web
# Page ID= Čelina_-LRB-Konjic-RRB-
# Page ID= XHZER-FM
# Page ID= Świerzów
# Page ID= You_Think_You're_Tough
# Page ID= Yifeng_Sun
# Page ID= Yuanzheng-1
# Page ID= York_Wilson
# Page ID= Xestocasis_balanochrysa
# Page ID= İncili,_Aydıntepe
# Page ID= Wólka_Okopska
# Page ID= Zofia_Dmuszewska
# Page ID= Çubukköy,_Mengen
# Page ID= Zainsk
# Page ID= Zhengzhang_Shangfang
# Page ID= Édgar_Barreto
# Page ID= Yevgeny_Zababakhin
# Page ID= Yukpa_people
# Page ID= Çivi,_Amasya
# Page ID= Xilin_District
# Page ID= Œthelwald_of_Deira
# Page ID= Youth_travel
# Page ID= Yalova_Earthquake_Monument
# Page ID= Xbox_-LRB-console-RRB-_special_limited_editions
# Page ID= Ydanis_Rodríguez
# Page ID= You_Be_Killin_Em
# Page ID= Xieleqiao
# Page ID= Ziarat,_Parsian
# Page ID= Yungay,_Chile
# Page ID= İsalar
# Page ID= Łukasz_Targosz
# Page ID= X-75_Volume_1
# Page ID= Yan_Gomes
# Page ID= Zoombies
# Page ID= Zanobi_Acciaioli
# Page ID= Xincheng_Station
# Page ID= Yury_Lonchakov
# Page ID= Zawady,_Gmina_Rzeczyca
# Page ID= Youngs_River_Falls
# Page ID= Yushanlu_Station
# Page ID= Yarem_Qayah-e_Olya
# Page ID= You_Ain't_Seen_Nothing_Yet_-LRB-album-RRB-
# Page ID= Yorba_Linda_Spotlight_Theater
# Page ID= Yan_Province
# Page ID= Último_Guerrero
# Page ID= Yū_Serizawa
# Page ID= Yang_Dong-hyun
# Page ID= Świerczyna,_Lublin_Voivodeship
# Page ID= XHPP-FM_-LRB-Fortín,_Veracruz-RRB-
# Page ID= Zusammen_geh'n
# Page ID= İnterbank
# Page ID= Yelizaveta_Yermolayeva
# Page ID= Đỗ_Thanh_Thịnh
# Page ID= Zaręby_Leśne
# Page ID= Yuri_Dubinin
# Page ID= Yitzhak_Olshan
# Page ID= Yao,_Osaka
# Page ID= Zimbabwe_Tourism_Authority
# Page ID= Xtreme_Racing
# Page ID= ZB716
# Page ID= Xinjiang_Television
# Page ID= Yuta_Matsumura
# Page ID= Yves_Bissouma
# Page ID= Zosel_Dam
# Page ID= Zarrin_Darreh
# Page ID= Łopuchowo,_Suwałki_County
# Page ID= Zoids_Saga
# Page ID= X-height
# Page ID= Wutong_Shen
# Page ID= Xylopia_elliptica
# Page ID= Yasuhiro_Nagahashi
# Page ID= Zhaozhou
# Page ID= `Adab
# Page ID= Zagorje_-LRB-Posušje-RRB-
# Page ID= Ørjan_Nilsen
# Page ID= Yasuyuki_Saigo
# Page ID= Wye_Tour
# Page ID= Zeynep_Ergun
# Page ID= You_Can_All_Join_In
# Page ID= Ōtaguro_Tomoo
# Page ID= Yaronsho_Ngalung
# Page ID= Wäinö_Aaltonen_Museum_of_Art
# Page ID= Öschbrig
# Page ID= Ånnsjön
# Page ID= Zahira_Zahir
# Page ID= Zbylut_Grzywacz
# Page ID= Željana_Zovko
# Page ID= X1_Centauri
# Page ID= Zipping_Along
# Page ID= Zotung
# Page ID= Władysław_Edward_Kronenberg
# Page ID= Wrestling_at_the_1998_Asian_Games_–_Men's_Greco-Roman_54_kg
# Page ID= Zunheboto
# Page ID= Žarko_Paspalj
# Page ID= Zeodera
# Page ID= Youth_Political_Awareness_PAC
# Page ID= Zixiao_Palace
# Page ID= Zana_Khan_District
# Page ID= Yarim-Lim_II
# Page ID= Ynys_Eilun
# Page ID= Zoltán_Adorján
# Page ID= Ángel_Maldonado
# Page ID= Yengidzha
# Page ID= Ótr
# Page ID= Yamanashi_Prefectural_Museum
# Page ID= ¡Volaré!_The_Very_Best_of_the_Gipsy_Kings
# Page ID= Zaruma
# Page ID= XSM-74
# Page ID= Załęże_Wielkie
# Page ID= Zwiefalter_Aach
# Page ID= Érd
# Page ID= Álvaro_Dias
# Page ID= Zrizer
# Page ID= Zénaïde_Rossi
# Page ID= Yiannis_Andrianopoulos
# Page ID= Wynken,_Blynken_and_Nod_-LRB-film-RRB-
# Page ID= École_nationale_supérieure_des_Beaux-Arts
# Page ID= Zaręby-Skórki
# Page ID= Yuryevets
# Page ID= Yan_Ni
# Page ID= Zbaków_Dolny
# Page ID= Španje
# Page ID= Yinka_Olukunga
# Page ID= Zayd_ibn_Thabit
# Page ID= Yari_-LRB-disambiguation-RRB-
# Page ID= Zoetermeer_Panthers
# Page ID= Wyoming_Highway_174
# Page ID= £$€
# Page ID= Yuba,_Oklahoma
# Page ID= Y_Fflam
# Page ID= Wyse_Fork_Confederate_order_of_battle
# Page ID= Wrestling_at_the_2008_Summer_Olympics_–_Men's_Greco-Roman_60_kg
# Page ID= Zalesie-Kolonia,_Greater_Poland_Voivodeship
# Page ID= Yuze-Onsen_Station
# Page ID= Zignoichthys
# Page ID= Xu_Fu
# Page ID= Zach_Zarba
# Page ID= Ö1_Campus
# Page ID= Yamagata
# Page ID= Yared_Hagos
# Page ID= Zero_Tolerance_-LRB-2015_film-RRB-
# Page ID= Yurio_Akitomi
# Page ID= Wufenpu
# Page ID= Zhang_Tianai
# Page ID= Çolaxlı
# Page ID= Zig_Zag_Girl
# Page ID= Yeo_Seung-won
# Page ID= Yasuko_Fujii
# Page ID= Yermakovsky_District
# Page ID= Yang_Province
# Page ID= Zygmunt_Janiszewski
# Page ID= Ypsolopha_walsinghamiella
# Page ID= Yisa_Yu
# Page ID= You_Can't_Judge_a_Book_by_the_Cover
# Page ID= You_Keep_Coming_Back_Like_a_Song
# Page ID= Yamut
# Page ID= Yacine_Amaouche
# Page ID= Youth_Without_Youth
# Page ID= Yasuki_Kimoto
# Page ID= Zachman_Framework
# Page ID= Zatula
# Page ID= Örebro_Airport
# Page ID= Zoë_Tyler
# Page ID= Yvetot
# Page ID= Yūki_Ōtsu
# Page ID= Čudnić
# Page ID= X2vnc
# Page ID= Zadok_-LRB-disambiguation-RRB-
# Page ID= Zavarov
# Page ID= Yosef_Garfinkel
# Page ID= Zofia_Albinowska-Minkiewiczowa
# Page ID= Zhivopisny_Bridge
# Page ID= Yunclillos
# Page ID= Yukon_Flats
# Page ID= Zozobra
# Page ID= Y-bar_shrimp_goby
# Page ID= Yuri_Samarin
# Page ID= ZP2
# Page ID= Yomra
# Page ID= Zhengdian
# Page ID= Xerocrassa_arturi
# Page ID= Çayköy,_Göynük
# Page ID= Étrabonne
# Page ID= Yousef_Madani_Tabrizi
# Page ID= Zawiya_-LRB-institution-RRB-
# Page ID= Yavuz_Ataç
# Page ID= Zorbeez
# Page ID= Złotniki,_Kalisz_County
# Page ID= Zemiropsis_papillaris
# Page ID= Ziaran
# Page ID= Zawadka,_Bieszczady_County
# Page ID= Your_Uncle_Dudley
# Page ID= Zhang_Lei_-LRB-investor-RRB-
# Page ID= Yorosso
# Page ID= Yantra,_Gabrovo_Province
# Page ID= Zoshchenko
# Page ID= Šaulys
# Page ID= XII_Venice_Challenge_Save_Cup_–_Doubles
# Page ID= Øystein_Sørensen
# Page ID= Łochyńsko
# Page ID= You_Are_Loved
# Page ID= Zettai
# Page ID= Zinc_finger_matrin-type_4
# Page ID= Yare_prison_riot
# Page ID= Zeynalabad,_Kerman
# Page ID= Yugoslav_Sign_Language
# Page ID= Yonese_Hanine
# Page ID= Wyngate,_Virginia
# Page ID= Władysław_Kowalski_-LRB-politician-RRB-
# Page ID= Zia_Sand
# Page ID= Yair_-LRB-name-RRB-
# Page ID= Znojile
# Page ID= Yellow_Bluff_Fort_Historic_State_Park
# Page ID= Yannick_Nézet-Séguin
# Page ID= Yazır,_Finike
# Page ID= Zakojca
# Page ID= Érik_Morales_vs._Marcos_Maidana
# Page ID= You_Gets_No_Love
# Page ID= Yong_Lee-ja
# Page ID= Ōma,_Aomori
# Page ID= XX_Corps_-LRB-Union_Army-RRB-
# Page ID= Zelenokumsk
# Page ID= Zarra's_Law
# Page ID= Zipper_-LRB-data_structure-RRB-
# Page ID= Zagon
# Page ID= Xinghua_Subdistrict,_Guangzhou
# Page ID= Zubair_Mohamed_Salih
# Page ID= Xochiltepec
# Page ID= Zande_languages
# Page ID= Øksendal_Church
# Page ID= Yao_Haijun
# Page ID= Włosty
# Page ID= Zabar_Kuh
# Page ID= Åsen_Station
# Page ID= Zelgno-Bezdół
# Page ID= Ça_ira_-_Il_fiume_della_rivolta
# Page ID= Yuli_Munoz
# Page ID= Zintan
# Page ID= Șteileu_River
# Page ID= Zwierzynek,_Pomeranian_Voivodeship
# Page ID= Xianlinhu_Station
# Page ID= Zulu_Rock
# Page ID= Ždírec_nad_Doubravou
# Page ID= Čarobnjaci
# Page ID= Ściborowice
# Page ID= Yemane_Negassi
# Page ID= Åmmeberg
# Page ID= Ypsilanti_Historic_District
# Page ID= Xyloschizon
# Page ID= Đerekarce
# Page ID= Álex_Barrera
# Page ID= Štefan_Zaťko
# Page ID= Yang_Huimin
# Page ID= Your_Love_-LRB-Marié_Digby_album-RRB-
# Page ID= Yves-André_Hubert
# Page ID= Zagreb_local_elections,_June_1920
# Page ID= Yuval_Delshad
# Page ID= Wu_Yingyin
# Page ID= Yeshey_Dorji
# Page ID= Zija_Azizov
# Page ID= Zielonka,_West_Pomeranian_Voivodeship
# Page ID= Łuszczów-Kolonia,_Łęczna_County
# Page ID= Özkan_Karabulut
# Page ID= Yonathan_Cabral
# Page ID= You_Can_Take_What's_Mine
# Page ID= Yugoslavia_at_the_1988_Summer_Olympics
# Page ID= Zimna_Woda,_Nidzica_County
# Page ID= Zreče
# Page ID= Yevgeni_Safonov_-LRB-Uzbekistani_footballer-RRB-
# Page ID= Xələftala
# Page ID= Šventežeris
# Page ID= Yesung
# Page ID= İleri
# Page ID= Wysocarz
# Page ID= Ypsolopha_dorsimaculella
# Page ID= Yuki_Yamazaki
# Page ID= Ziaur_Rahman
# Page ID= Xiao_Bai
# Page ID= Yokohama_International_School
# Page ID= Xi_Aquilae_b
# Page ID= Zorn_ring
# Page ID= Ya'ammu_Nubwoserre
# Page ID= XHKL-FM
# Page ID= Wyszobór
# Page ID= Ysgol_y_Gader
# Page ID= XHTXO-FM
# Page ID= Yunokawa_Onsen
# Page ID= Yana_Uqsha_-LRB-Ayacucho-RRB-
# Page ID= Wythoff's_game
# Page ID= Yarseli_Dam
# Page ID= Zieria_eungellaensis
# Page ID= Świniary,_Oleśnica_County
# Page ID= Șepreuș
# Page ID= Yoshi_Hijikata
# Page ID= Zhuqi
# Page ID= Yuan_Hai_Zi_Ping
# Page ID= À_gogo
# Page ID= Znamensky_-LRB-rural_locality-RRB-
# Page ID= YTR
# Page ID= Xplorair
# Page ID= Zimmerbach_-LRB-Starzel-RRB-
# Page ID= Yoder,_Colorado
# Page ID= İzmir'in_Kavakları
# Page ID= Ásta_Guðrún_Helgadóttir
# Page ID= Đại_Việt_Duy_Dân
# Page ID= Xi_Shengmo
# Page ID= Zirenkel_language
# Page ID= Xanthophyllum_beccarianum
# Page ID= Zubaan
# Page ID= Zygomaticotemporal_nerve
# Page ID= Zulema_Castro_de_Peña
# Page ID= Örebro_SK_Ungdom
# Page ID= Yeah_Yeah_-LRB-Sabrina_song-RRB-
# Page ID= Zhang_Yonghai
# Page ID= Xenorhabdus_kozodoii
# Page ID= Zachariah_Atinasio
# Page ID= Zaręby-Bolędy
# Page ID= Yukon,_Florida
# Page ID= Zhai_Xiaochuan
# Page ID= Zanzibar_barb
# Page ID= Yugoslav_Socialist_Association
# Page ID= Đồng_Huy_Thái
# Page ID= Xu_Jianguo
# Page ID= Xionites
# Page ID= Zemeș
# Page ID= Yoram_Gross
# Page ID= Youth_Development_Administration
# Page ID= Álvaro_Odriozola
# Page ID= Wuhan_Tianhe_International_Airport
# Page ID= Ćemalovići
# Page ID= Zoar_Strict_Baptist_Chapel
# Page ID= Żerniki_Dolne
# Page ID= Zeus_-LRB-musician-RRB-
# Page ID= Yield_curve_-LRB-disambiguation-RRB-
# Page ID= Yelo
# Page ID= Éloi_Firmin_Féron
# Page ID= Yang_Kyung-soo
# Page ID= Yosemite_Valley_Lodge
# Page ID= Yolett_McPhee-McCuin
# Page ID= Xenotrachea
# Page ID= Zookeeper_-LRB-film-RRB-
# Page ID= Yurie_Miura
# Page ID= Yaysky_District
# Page ID= Zinc_finger_protein_784
# Page ID= Written_in_Blood_-LRB-novel-RRB-
# Page ID= Zeng_Qi
# Page ID= Émile_Moreau_-LRB-politician-RRB-
# Page ID= Zénaïde_Fleuriot
# Page ID= Zalman_Moishe_HaYitzchaki
# Page ID= Young_JV
# Page ID= Zénon_Bacq
# Page ID= Yaw_Ansong_Jr.
# Page ID= Wrottesley
# Page ID= Your_Heart_Breaks
# Page ID= Wynne_baronets
# Page ID= Zeadmete_ovalis
# Page ID= Zgraja_coat_of_arms
# Page ID= Zgliczyn_Witowy
# Page ID= École_nationale_supérieure_des_arts_appliqués_et_des_métiers_d'art
# Page ID= Zana
# Page ID= York_City_F.C.
# Page ID= Zlatina_Deliradeva
# Page ID= Year_Zero_-LRB-Bernice_Summerfield-RRB-
# Page ID= Yves_Oehri
# Page ID= İsabeyli
# Page ID= Yelena_Nikolayeva_-LRB-racewalker-RRB-
# Page ID= Yinxiang_-LRB-prince-RRB-
# Page ID= Yeşilöz,_Batman
# Page ID= Xenolechia_pseudovulgella
# Page ID= Wygoda,_Zwoleń_County
# Page ID= Wągrowiec_County
# Page ID= Yuto_Agarie
# Page ID= Yume_1_Go
# Page ID= Yada_Yada_-LRB-album-RRB-
# Page ID= Xylorycta_bipunctella
# Page ID= Łęczyce,_Greater_Poland_Voivodeship
